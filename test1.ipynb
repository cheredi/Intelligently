# %% [markdown]
# **IMPORTS**

# %%
from keras.models import load_model
import numpy as np 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Compute Euclidean Distance Loss  between
# 	input frame and the reconstructed frame

# %%
def mean_squared_loss(x1,x2):
  diff=x1-x2
  a,b,c,d,e=diff.shape
  n_samples=a*b*c*d*e
  sq_diff=diff**2
  Sum=sq_diff.sum()
  dist=np.sqrt(Sum)
  mean_dist=dist/n_samples

  return mean_dist

# %% [markdown]
# **DEFINE THRESHOLD**

# %%
threshold=0.1

# %% [markdown]
# **LOAD TRAINED MODEL AND EXTRACTED NUMPY FILE**

# %%
model=load_model('Model.h5')

X_test=np.load('test.npy')
frames=X_test.shape[2]

# %%
flag=0 

frames=frames-frames%10

# %% [markdown]
# **BEGIN TESTING AND DEFINE ANOMALY OR NORMAL EVENTS**

# %%
X_test=X_test[:,:,:frames]
X_test=X_test.reshape(-1,227,227,10)
X_test=np.expand_dims(X_test,axis=4)

for number,bunch in enumerate(X_test):
	n_bunch=np.expand_dims(bunch,axis=0)
	reconstructed_bunch=model.predict(n_bunch)


	loss=mean_squared_loss(n_bunch,reconstructed_bunch)

	if loss>threshold:
		print("Anomalous bunch of frames at bunch number {}".format(number))
		flag=1


	else:
		print('Bunch Normal')



if flag==1:
	print("Anomalous Events detected")
