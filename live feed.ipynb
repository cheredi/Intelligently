# %% [markdown]
# **IMPORTS**

# %%
import cv2
import numpy as np 
from skimage.transform import resize
from keras.models import load_model
import argparse
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **DEFINE THE DIRECTORY PATH**

# %%
parser=argparse.ArgumentParser()

parser.add_argument('modelpath',type=str)

args=parser.parse_args('/content/drive/MyDrive/Anomaly Detection/model/model.h5')

modelpath=args.modelpath

# %% [markdown]
# **LOAD MODEL**

# %%
vc=cv2.VideoCapture(0)
rval=True
print('Loading model')
model=load_model(modelpath)
print('Model loaded')

# %% [markdown]
# **EXTRACT FRAMES FROM LIVE FEED VIDEO AND CONVERT IT INTO AN ARRAY**

# %%
threshold=0.1
while True:
	imagedump=[]
	for i in range(10):
		rval,frame=vc.read()
		frame=resize(frame,(227,227,3))

		#Convert the Image to Grayscale


		gray=0.2989*frame[:,:,0]+0.5870*frame[:,:,1]+0.1140*frame[:,:,2]
		gray=(gray-gray.mean())/gray.std()
		gray=np.clip(gray,0,1)
		imagedump.append(gray)


	imagedump=np.array(imagedump)

	imagedump.resize(227,227,10)
	imagedump=np.expand_dims(imagedump,axis=0)
	imagedump=np.expand_dims(imagedump,axis=4)


	print('Processing data')

# %% [markdown]
# **USE TRAINED MODEL TO PREDICT ANOMALIES**

# %%
output=model.predict(imagedump)



	loss=mean_squared_loss(imagedump,output)


	if loss>threshold:
		print('Anomalies Detected')
